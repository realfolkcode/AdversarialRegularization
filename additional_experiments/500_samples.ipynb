# %% [markdown]
# # Install and import

# %%
import os
import torch
import torchvision
from torchvision import transforms
from torch import nn
from torch.utils.data import Dataset, DataLoader, Subset
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
# %matplotlib inline

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
# !git clone https://github.com/realfolkcode/AdversarialRegularization.git
# Out:
# Cloning into 'AdversarialRegularization'...
# remote: Enumerating objects: 83, done.
# remote: Counting objects: 100% (83/83), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 83 (delta 36), reused 22 (delta 6), pack-reused 0
# Unpacking objects: 100% (83/83), done.

# %%
from AdversarialRegularization.utils import *

# %% [markdown]
# # Loading Models

# %%
class CNN(nn.Module):
    def __init__(self, num_classes=100):
        super(CNN, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(),

            nn.Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(),

            nn.Conv2d(128, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(),

            nn.Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False),
            nn.BatchNorm2d(256),
            nn.ReLU(),
        )
        self.classifier = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        batch_size = x.shape[0]
        x = self.features(x)
        x = self.classifier(x)
        return x

# %% [markdown]
# We want to collect good filters. For that purpose, we load models that have been trained on a large dataset. These models differ only in initial weight initialization.

# %%
model_dir = 'AdversarialRegularization/models/'
model_lst = []

for model_name in os.listdir('AdversarialRegularization/models/'):
    model_path = os.path.join(model_dir, model_name)
    model = CNN(num_classes=100)
    model.load_state_dict(torch.load(model_path, map_location='cpu'))
    model_lst.append(model)

# %%
print('Number of models:', len(model_lst))
# Out:
# Number of models: 5

# %% [markdown]
# # Filter Dataset

# %% [markdown]
# Let us create a class for filters dataset to make life easier. We will use it to train discriminators. As input, it would take a list of convolution layers (kernel sizes must be the same).

# %%
class FilterDataset(Dataset):
    def __init__(self, layer_lst):
        self.kernels = [layer.weight.data.clone() for layer in layer_lst]
        self.kernels = torch.cat(self.kernels)
        c_out, c_in, h, w = self.kernels.shape
        self.kernels = self.kernels.view(c_out * c_in, -1, h, w)
    
    def __len__(self):
        return len(self.kernels)
    
    def __getitem__(self, idx):
        return self.kernels[idx]

# %%
RANDOM_SEED = 0
set_random_seeds(seed_value=RANDOM_SEED, device=device)

# %%
filters_data = []
filters_loader = []

# Create datasets for 7x7, 5x5, 5x5 kernels from corresponding convolution layers 
filters_data.append(FilterDataset([model.features[0] for model in model_lst]))
filters_data.append(FilterDataset([model_lst[0].features[3]]))
filters_data.append(FilterDataset([model_lst[0].features[6]]))

# Create dataloaders for filters datasets
for i in range(len(filters_data)):
    filters_loader.append(DataLoader(filters_data[i], batch_size=128, shuffle=True))

# %%
for i in range(len(filters_loader)):
    print(f'Filter Dataset {i} size: {len(filters_loader[i].dataset)}')
# Out:
# Filter Dataset 0 size: 960
# Filter Dataset 1 size: 8192
# Filter Dataset 2 size: 16384

# %% [markdown]
# Now, we can iterate over filters dataset.

# %% [markdown]
# We can also visualize kernels to check if our dataset contains patterns.

# %%
def plot_kernels(loader, nrow=8):
    dataiter = iter(loader)
    batch = dataiter.next()
    rows = np.min((batch.shape[0] // nrow + 1, 64))    
    grid = torchvision.utils.make_grid(batch, nrow=nrow, normalize=True, padding=1)
    grid = grid.to(device=torch.device("cpu")) 
    plt.figure(figsize=(nrow,rows))
    plt.imshow(grid.numpy().transpose((1, 2, 0)), cmap='coolwarm')

# %%
plot_kernels(filters_loader[0], nrow=9)

# %%
plot_kernels(filters_loader[1], nrow=9)

# %%
plot_kernels(filters_loader[2], nrow=9)

# %% [markdown]
# # Prepare data

# %% [markdown]
# Now we load CIFAR10 and take a small subset of it. We restrict this subset to have equal number of images per class to make dataset balanced.

# %%
train_transform = transforms.Compose([transforms.ToTensor(),
                                      transforms.Normalize(0.5, 0.5)])
test_transform = transforms.Compose([transforms.ToTensor(),
                                     transforms.Normalize(0.5, 0.5)])

train_set = torchvision.datasets.CIFAR10('./cifar10', train=True, download=True,
                                         transform=train_transform)

test_set = torchvision.datasets.CIFAR10('./cifar10', train=False, download=True,
                                        transform=test_transform)

print('Train size', len(train_set))
print('Test size', len(test_set))
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar10/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./cifar10/cifar-10-python.tar.gz to ./cifar10
# Files already downloaded and verified
# Train size 50000
# Test size 10000

# %%
train_size = 500 / len(train_set)

# %%
train_idx, _ = train_test_split(np.arange(len(train_set)),
                                train_size=train_size,
                                shuffle=True,
                                random_state=42,
                                stratify=train_set.targets)

# %% [markdown]
# Let's make sure that the obtained indices are indeed stratified by classes.

# %%
pd.DataFrame(train_set.targets).rename(columns={0: 'class'}).iloc[train_idx].groupby('class').size()
# Out:
# class
# 0    50
# 1    50
# 2    50
# 3    50
# 4    50
# 5    50
# 6    50
# 7    50
# 8    50
# 9    50
# dtype: int64

# %%
train_set = Subset(train_set, train_idx)

# %%
batch_size = 16

train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=2)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size, shuffle=False, num_workers=2)

# %%
plot_random_images(train_loader)

# %%
plot_random_images(test_loader)

# %% [markdown]
# # Training on small dataset

# %%
def epoch_train(loader, clf, criterion, opt):
    clf.train()
    for data, target in loader:
        data = data.to(device)
        target = target.to(device)
        output = clf(data)
        loss = criterion(output, target)

        opt.zero_grad()
        loss.backward()
        opt.step()
    
    clf.eval()
    train_loss = 0
    with torch.no_grad():
        for data, target in loader:
            data = data.to(device)
            target = target.to(device)
            output = clf(data)
            train_loss += criterion(output, target).item()
    train_acc = get_accuracy(clf, loader, device)
    train_loss /= len(loader.dataset)
    return train_loss, train_acc


def epoch_test(loader, clf, criterion):
    clf.eval()
    test_loss = 0
    with torch.no_grad():
        for data, target in loader:
            data = data.to(device)
            target = target.to(device)
            output = clf(data)
            test_loss += criterion(output, target).item()
    test_acc = get_accuracy(clf, loader, device)
    test_loss /= len(loader.dataset)
    return test_loss, test_acc


def train(train_loader, test_loader, clf, criterion, opt, n_epochs=50):
    test_scores = []
    for epoch in range(n_epochs):
        train_loss, train_acc = epoch_train(train_loader, clf, criterion, opt)
        if epoch % 10 == 9:
            test_loss, test_acc = epoch_test(test_loader, clf, criterion)
            test_scores.append(test_acc)
            print(f'[Epoch {epoch + 1}] train loss: {train_loss:.3f}; train acc: {train_acc:.2f}; ' + 
                  f'test loss: {test_loss:.3f}; test acc: {test_acc:.2f}')
    return test_scores

# %%
torch.cuda.set_device(0)
clf = CNN(num_classes=10).cuda()
print('Number of weights:', np.sum([np.prod(p.shape) for p in clf.parameters()]))
    
# Check that the output size of the network is BATCH_SIZE x NUM_CLASSES
X = next(iter(train_loader))[0].cuda()
with torch.no_grad():
    clf_X = clf(X)
    assert len(clf_X) == len(X)
    assert clf_X.shape[1] == 10
# Out:
# Number of weights: 922442

# %%
opt_clf = torch.optim.Adam(clf.parameters(), lr=2e-4, weight_decay=1e-4, betas=(0.5, 0.999))
criterion = torch.nn.CrossEntropyLoss()
test_scores = train(train_loader, test_loader, clf, criterion, opt_clf, n_epochs=1000)
# Out:
# [Epoch 10] train loss: 0.006; train acc: 0.99; test loss: 0.131; test acc: 0.28
# [Epoch 20] train loss: 0.001; train acc: 1.00; test loss: 0.122; test acc: 0.32
# [Epoch 30] train loss: 0.001; train acc: 1.00; test loss: 0.133; test acc: 0.30
# [Epoch 40] train loss: 0.000; train acc: 1.00; test loss: 0.134; test acc: 0.32
# [Epoch 50] train loss: 0.000; train acc: 1.00; test loss: 0.135; test acc: 0.31
# [Epoch 60] train loss: 0.004; train acc: 0.99; test loss: 0.149; test acc: 0.28
# [Epoch 70] train loss: 0.000; train acc: 1.00; test loss: 0.148; test acc: 0.30
# [Epoch 80] train loss: 0.002; train acc: 0.99; test loss: 0.179; test acc: 0.25
# [Epoch 90] train loss: 0.000; train acc: 1.00; test loss: 0.162; test acc: 0.29
# [Epoch 100] train loss: 0.000; train acc: 1.00; test loss: 0.157; test acc: 0.30
# [Epoch 110] train loss: 0.000; train acc: 1.00; test loss: 0.166; test acc: 0.28
# [Epoch 120] train loss: 0.000; train acc: 1.00; test loss: 0.160; test acc: 0.30
# [Epoch 130] train loss: 0.000; train acc: 1.00; test loss: 0.163; test acc: 0.30
# [Epoch 140] train loss: 0.000; train acc: 1.00; test loss: 0.177; test acc: 0.27
# [Epoch 150] train loss: 0.000; train acc: 1.00; test loss: 0.169; test acc: 0.29
# [Epoch 160] train loss: 0.004; train acc: 0.98; test loss: 0.221; test acc: 0.24
# [Epoch 170] train loss: 0.000; train acc: 1.00; test loss: 0.186; test acc: 0.29
# [Epoch 180] train loss: 0.000; train acc: 1.00; test loss: 0.199; test acc: 0.27
# [Epoch 190] train loss: 0.000; train acc: 1.00; test loss: 0.181; test acc: 0.29
# [Epoch 200] train loss: 0.000; train acc: 1.00; test loss: 0.198; test acc: 0.27
# [Epoch 210] train loss: 0.003; train acc: 0.99; test loss: 0.199; test acc: 0.27
# [Epoch 220] train loss: 0.000; train acc: 1.00; test loss: 0.188; test acc: 0.27
# [Epoch 230] train loss: 0.000; train acc: 1.00; test loss: 0.189; test acc: 0.29
# [Epoch 240] train loss: 0.002; train acc: 0.99; test loss: 0.197; test acc: 0.27
# [Epoch 250] train loss: 0.000; train acc: 1.00; test loss: 0.186; test acc: 0.30
# [Epoch 260] train loss: 0.000; train acc: 1.00; test loss: 0.190; test acc: 0.29
# [Epoch 270] train loss: 0.000; train acc: 1.00; test loss: 0.202; test acc: 0.26
# [Epoch 280] train loss: 0.000; train acc: 1.00; test loss: 0.190; test acc: 0.28
# [Epoch 290] train loss: 0.000; train acc: 1.00; test loss: 0.198; test acc: 0.28
# [Epoch 300] train loss: 0.000; train acc: 1.00; test loss: 0.197; test acc: 0.28
# [Epoch 310] train loss: 0.002; train acc: 1.00; test loss: 0.207; test acc: 0.26
# [Epoch 320] train loss: 0.000; train acc: 1.00; test loss: 0.190; test acc: 0.28
# [Epoch 330] train loss: 0.000; train acc: 1.00; test loss: 0.198; test acc: 0.29
# [Epoch 340] train loss: 0.000; train acc: 1.00; test loss: 0.210; test acc: 0.28
# [Epoch 350] train loss: 0.000; train acc: 1.00; test loss: 0.197; test acc: 0.29
# [Epoch 360] train loss: 0.000; train acc: 1.00; test loss: 0.205; test acc: 0.28
# [Epoch 370] train loss: 0.000; train acc: 1.00; test loss: 0.204; test acc: 0.28
# [Epoch 380] train loss: 0.000; train acc: 1.00; test loss: 0.201; test acc: 0.28
# [Epoch 390] train loss: 0.000; train acc: 1.00; test loss: 0.210; test acc: 0.27
# [Epoch 400] train loss: 0.000; train acc: 1.00; test loss: 0.200; test acc: 0.28
# [Epoch 410] train loss: 0.000; train acc: 1.00; test loss: 0.208; test acc: 0.27
# [Epoch 420] train loss: 0.000; train acc: 1.00; test loss: 0.207; test acc: 0.28
# [Epoch 430] train loss: 0.000; train acc: 1.00; test loss: 0.212; test acc: 0.29
# [Epoch 440] train loss: 0.000; train acc: 1.00; test loss: 0.197; test acc: 0.27
# [Epoch 450] train loss: 0.000; train acc: 1.00; test loss: 0.199; test acc: 0.28
# [Epoch 460] train loss: 0.000; train acc: 1.00; test loss: 0.200; test acc: 0.27
# [Epoch 470] train loss: 0.000; train acc: 1.00; test loss: 0.204; test acc: 0.28
# [Epoch 480] train loss: 0.000; train acc: 1.00; test loss: 0.205; test acc: 0.28
# [Epoch 490] train loss: 0.004; train acc: 0.98; test loss: 0.234; test acc: 0.24
# [Epoch 500] train loss: 0.000; train acc: 1.00; test loss: 0.203; test acc: 0.27
# [Epoch 510] train loss: 0.000; train acc: 1.00; test loss: 0.208; test acc: 0.27
# [Epoch 520] train loss: 0.000; train acc: 1.00; test loss: 0.206; test acc: 0.28
# [Epoch 530] train loss: 0.000; train acc: 1.00; test loss: 0.205; test acc: 0.29
# [Epoch 540] train loss: 0.000; train acc: 1.00; test loss: 0.220; test acc: 0.26
# [Epoch 550] train loss: 0.000; train acc: 1.00; test loss: 0.210; test acc: 0.27
# [Epoch 560] train loss: 0.000; train acc: 1.00; test loss: 0.204; test acc: 0.28
# [Epoch 570] train loss: 0.000; train acc: 1.00; test loss: 0.202; test acc: 0.28
# [Epoch 580] train loss: 0.000; train acc: 1.00; test loss: 0.199; test acc: 0.28
# [Epoch 590] train loss: 0.000; train acc: 1.00; test loss: 0.200; test acc: 0.29
# [Epoch 600] train loss: 0.000; train acc: 1.00; test loss: 0.206; test acc: 0.28
# [Epoch 610] train loss: 0.000; train acc: 1.00; test loss: 0.206; test acc: 0.28
# [Epoch 620] train loss: 0.000; train acc: 1.00; test loss: 0.205; test acc: 0.29
# [Epoch 630] train loss: 0.000; train acc: 1.00; test loss: 0.203; test acc: 0.27
# [Epoch 640] train loss: 0.000; train acc: 1.00; test loss: 0.206; test acc: 0.28
# [Epoch 650] train loss: 0.000; train acc: 1.00; test loss: 0.218; test acc: 0.27
# [Epoch 660] train loss: 0.000; train acc: 1.00; test loss: 0.205; test acc: 0.28
# [Epoch 670] train loss: 0.000; train acc: 1.00; test loss: 0.209; test acc: 0.27
# [Epoch 680] train loss: 0.000; train acc: 1.00; test loss: 0.212; test acc: 0.27
# [Epoch 690] train loss: 0.000; train acc: 1.00; test loss: 0.206; test acc: 0.27
# [Epoch 700] train loss: 0.000; train acc: 1.00; test loss: 0.207; test acc: 0.27
# [Epoch 710] train loss: 0.000; train acc: 1.00; test loss: 0.206; test acc: 0.27
# [Epoch 720] train loss: 0.000; train acc: 1.00; test loss: 0.217; test acc: 0.27
# [Epoch 730] train loss: 0.000; train acc: 1.00; test loss: 0.211; test acc: 0.28
# [Epoch 740] train loss: 0.000; train acc: 1.00; test loss: 0.211; test acc: 0.27
# [Epoch 750] train loss: 0.000; train acc: 1.00; test loss: 0.211; test acc: 0.27
# [Epoch 760] train loss: 0.000; train acc: 1.00; test loss: 0.211; test acc: 0.27
# [Epoch 770] train loss: 0.000; train acc: 1.00; test loss: 0.203; test acc: 0.28
# [Epoch 780] train loss: 0.000; train acc: 1.00; test loss: 0.204; test acc: 0.29
# [Epoch 790] train loss: 0.000; train acc: 1.00; test loss: 0.209; test acc: 0.27
# [Epoch 800] train loss: 0.000; train acc: 1.00; test loss: 0.216; test acc: 0.26
# [Epoch 810] train loss: 0.000; train acc: 1.00; test loss: 0.219; test acc: 0.27
# [Epoch 820] train loss: 0.000; train acc: 1.00; test loss: 0.209; test acc: 0.27
# [Epoch 830] train loss: 0.000; train acc: 1.00; test loss: 0.212; test acc: 0.28
# [Epoch 840] train loss: 0.000; train acc: 1.00; test loss: 0.213; test acc: 0.27
# [Epoch 850] train loss: 0.000; train acc: 1.00; test loss: 0.213; test acc: 0.28
# [Epoch 860] train loss: 0.000; train acc: 1.00; test loss: 0.209; test acc: 0.28
# [Epoch 870] train loss: 0.000; train acc: 1.00; test loss: 0.221; test acc: 0.27
# [Epoch 880] train loss: 0.000; train acc: 1.00; test loss: 0.208; test acc: 0.28
# [Epoch 890] train loss: 0.000; train acc: 1.00; test loss: 0.221; test acc: 0.27
# [Epoch 900] train loss: 0.000; train acc: 1.00; test loss: 0.218; test acc: 0.26
# [Epoch 910] train loss: 0.000; train acc: 1.00; test loss: 0.209; test acc: 0.28
# [Epoch 920] train loss: 0.000; train acc: 1.00; test loss: 0.219; test acc: 0.27
# [Epoch 930] train loss: 0.000; train acc: 1.00; test loss: 0.216; test acc: 0.26
# [Epoch 940] train loss: 0.000; train acc: 1.00; test loss: 0.218; test acc: 0.27
# [Epoch 950] train loss: 0.000; train acc: 1.00; test loss: 0.216; test acc: 0.27
# [Epoch 960] train loss: 0.000; train acc: 1.00; test loss: 0.211; test acc: 0.27
# [Epoch 970] train loss: 0.000; train acc: 1.00; test loss: 0.214; test acc: 0.27
# [Epoch 980] train loss: 0.000; train acc: 1.00; test loss: 0.214; test acc: 0.27
# [Epoch 990] train loss: 0.000; train acc: 1.00; test loss: 0.223; test acc: 0.25
# [Epoch 1000] train loss: 0.000; train acc: 1.00; test loss: 0.218; test acc: 0.26

# %%
filters_data_small = []
filters_loader_small = []
# Create datasets for 7x7, 5x5, 5x5 kernels from corresponding convolution layers 
filters_data_small.append(FilterDataset([clf.features[0]]))
filters_data_small.append(FilterDataset([clf.features[3]]))
filters_data_small.append(FilterDataset([clf.features[6]]))

# Create dataloaders for filters datasets
for i in range(len(filters_data_small)):
    filters_loader_small.append(DataLoader(filters_data_small[i], batch_size=128, shuffle=True))

# %%
plot_kernels(filters_loader_small[0], nrow=9)

# %%
plot_kernels(filters_loader_small[1], nrow=9)

# %%
plot_kernels(filters_loader_small[2], nrow=9)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
plt.figure(figsize=(12, 8))
plt.plot(np.arange(1, 1001, 10), test_scores)
plt.xlabel('Epoch', size=18)
plt.ylabel('Accuracy', size=18)
plt.title('Test accuracy', size=18)
plt.show()
plt.savefig('plot.png')
