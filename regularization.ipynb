# %% [markdown]
# <a href="https://colab.research.google.com/github/realfolkcode/AdversarialRegularization/blob/main/regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install and import

# %%
import os
import torch
import torchvision
from torchvision import transforms
from torch import nn
from torch.utils.data import Dataset, DataLoader, Subset
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
# %matplotlib inline

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
# !git clone https://github.com/realfolkcode/AdversarialRegularization.git
# Out:
# Cloning into 'AdversarialRegularization'...
# remote: Enumerating objects: 80, done.
# remote: Counting objects: 100% (80/80), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 80 (delta 35), reused 22 (delta 6), pack-reused 0
# Unpacking objects: 100% (80/80), done.

# %%
from AdversarialRegularization.utils import *

# %% [markdown]
# # Loading Models

# %%
class CNN(nn.Module):
    def __init__(self, num_classes=100):
        super(CNN, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(),

            nn.Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(),

            nn.Conv2d(128, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(),

            nn.Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False),
            nn.BatchNorm2d(256),
            nn.ReLU(),
        )
        self.classifier = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        batch_size = x.shape[0]
        x = self.features(x)
        x = self.classifier(x)
        return x

# %% [markdown]
# We want to collect good filters. For that purpose, we load models that have been trained on a large dataset. These models differ only in initial weight initialization.

# %%
model_dir = 'AdversarialRegularization/models/'
model_lst = []

for model_name in os.listdir('AdversarialRegularization/models/'):
    model_path = os.path.join(model_dir, model_name)
    model = CNN(num_classes=100)
    model.load_state_dict(torch.load(model_path, map_location='cpu'))
    model_lst.append(model)

# %%
model_lst[0]
# Out:
# CNN(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), bias=False)
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Conv2d(128, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), bias=False)
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#     (9): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (10): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): ReLU()
#   )
#   (classifier): Sequential(
#     (0): AdaptiveAvgPool2d(output_size=1)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): Linear(in_features=256, out_features=100, bias=True)
#   )
# )

# %%
print('Number of models:', len(model_lst))
# Out:
# Number of models: 5

# %% [markdown]
# # Filter Dataset

# %% [markdown]
# Let us create a class for filters dataset to make life easier. We will use it to train discriminators. As input, it would take a list of convolution layers (kernel sizes must be the same).

# %%
# A freezed dataset of filters that does not stores gradients.

class FilterDataset(Dataset):
    def __init__(self, layer_lst):
        self.kernels = [layer.weight.data.clone() for layer in layer_lst]
        self.kernels = torch.cat(self.kernels)
        c_out, c_in, h, w = self.kernels.shape
        self.kernels = self.kernels.view(c_out * c_in, -1, h, w)
    
    def __len__(self):
        return len(self.kernels)
    
    def __getitem__(self, idx):
        return self.kernels[idx]

# %%
# A differentiable version of this dataset. We use it to construct dataset of filters to train generative part of classifier.

class ParameterFilterDataset(Dataset):
    def __init__(self, layer):
        self.kernels = layer.weight
        c_out, c_in, h, w = self.kernels.shape
        self.kernels = self.kernels.view(c_out * c_in, -1, h, w)
    
    def __len__(self):
        return len(self.kernels)
    
    def __getitem__(self, idx):
        return self.kernels[idx]

# %%
model_lst[0].features[0]
# Out:
# Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)

# %%
RANDOM_SEED = 0
set_random_seeds(seed_value=RANDOM_SEED, device=device)

# %%
filter_bs = 128

filters_data = []
filters_loader = []

# Create datasets for 7x7, 5x5, 5x5 kernels from corresponding convolution layers 
filters_data.append(FilterDataset([model.features[0] for model in model_lst]))
filters_data.append(FilterDataset([model_lst[0].features[3]]))
filters_data.append(FilterDataset([model_lst[0].features[6]]))

# Create dataloaders for filters datasets
for i in range(len(filters_data)):
    filters_loader.append(DataLoader(filters_data[i], batch_size=filter_bs, shuffle=True))

# %%
for i in range(len(filters_loader)):
    print(f'Filter Dataset {i} size: {len(filters_loader[i].dataset)}')
# Out:
# Filter Dataset 0 size: 960
# Filter Dataset 1 size: 8192
# Filter Dataset 2 size: 16384

# %% [markdown]
# Now, we can iterate over filters dataset.

# %%
for batch in filters_loader[0]:
    print(batch)
    break
# Out:
# tensor([[[[-0.0879, -0.0739, -0.0795,  ...,  0.0731,  0.0798,  0.0049],
#           [-0.0744,  0.0545,  0.0253,  ...,  0.2629,  0.1220,  0.0514],
#           [ 0.0422,  0.2136,  0.3394,  ...,  0.2163, -0.0506, -0.2390],
#           ...,
#           [ 0.1515,  0.1743, -0.0196,  ..., -0.3626, -0.2900, -0.0979],
#           [ 0.0293,  0.0629, -0.1564,  ..., -0.2374, -0.1608,  0.0408],
#           [-0.0488, -0.0688, -0.1477,  ..., -0.0452,  0.0429,  0.2405]]],
#
#
#         [[[ 0.0025,  0.0336, -0.0175,  ...,  0.1137,  0.1465,  0.1374],
#           [-0.0019,  0.0114,  0.0537,  ...,  0.1063,  0.1444,  0.0270],
#           [ 0.0727,  0.0320,  0.0763,  ...,  0.1393,  0.1422,  0.0022],
#           ...,
#           [ 0.0276, -0.0455,  0.0459,  ..., -0.0118, -0.0496, -0.1666],
#           [ 0.0085, -0.0285, -0.0370,  ..., -0.1572, -0.1378, -0.1835],
#           [-0.0284, -0.1524, -0.2105,  ..., -0.2875, -0.1830, -0.2405]]],
#
#
#         [[[ 0.0039, -0.0441, -0.0199,  ...,  0.0432, -0.0778, -0.0106],
#           [ 0.0023,  0.0413, -0.1102,  ...,  0.1243, -0.1075,  0.0684],
#           [ 0.0358,  0.0137,  0.0506,  ...,  0.2601, -0.2414,  0.0844],
#           ...,
#           [ 0.0024,  0.0171, -0.0191,  ...,  0.3004, -0.2421,  0.0375],
#           [-0.0584, -0.0494,  0.0735,  ...,  0.1844, -0.1865,  0.0257],
#           [ 0.0519, -0.0045, -0.0124,  ...,  0.1410, -0.1439,  0.0458]]],
#
#
#         ...,
#
#
#         [[[ 0.0280, -0.0074,  0.0633,  ...,  0.0089,  0.0885,  0.1739],
#           [-0.1495, -0.0616, -0.1986,  ..., -0.0656,  0.0231,  0.1067],
#           [-0.2366, -0.2585, -0.1957,  ..., -0.1381, -0.0159,  0.0583],
#           ...,
#           [-0.1420, -0.2643, -0.2998,  ..., -0.2616, -0.0610, -0.0814],
#           [-0.1703, -0.1617, -0.2799,  ..., -0.1770, -0.1152,  0.0604],
#           [-0.0359, -0.1020, -0.1647,  ..., -0.1088, -0.0876,  0.0702]]],
#
#
#         [[[-0.0024, -0.0157, -0.0809,  ..., -0.0882, -0.0799, -0.0673],
#           [-0.0420,  0.0107, -0.0856,  ..., -0.1742, -0.0727, -0.0929],
#           [ 0.0244,  0.0356, -0.0223,  ...,  0.0657,  0.1088,  0.1204],
#           ...,
#           [ 0.0521,  0.1012,  0.1009,  ...,  0.1021,  0.0545, -0.0094],
#           [ 0.0100,  0.0396, -0.0336,  ..., -0.1435, -0.1445, -0.1118],
#           [-0.1170, -0.1532, -0.1481,  ..., -0.2292, -0.1880, -0.1264]]],
#
#
#         [[[ 0.0959, -0.0703,  0.0021,  ...,  0.0117,  0.0375,  0.0075],
#           [ 0.0887,  0.0297, -0.0632,  ...,  0.0820,  0.0467, -0.1069],
#           [-0.0419, -0.1218, -0.0741,  ...,  0.1473, -0.0106, -0.1809],
#           ...,
#           [-0.0569, -0.0850,  0.0161,  ...,  0.1308, -0.1002, -0.2320],
#           [-0.0546, -0.1313, -0.0191,  ...,  0.1271, -0.1214, -0.1604],
#           [ 0.0039, -0.0426,  0.0791,  ...,  0.1022, -0.0334, -0.0499]]]])

# %% [markdown]
# We can also visualize kernels to check if our dataset contains patterns.

# %%
def plot_kernels(loader, nrow=8):
    dataiter = iter(loader)
    batch = dataiter.next()
    rows = np.min((batch.shape[0] // nrow + 1, 64))    
    grid = torchvision.utils.make_grid(batch, nrow=nrow, normalize=True, padding=1)
    plt.figure(figsize=(nrow,rows))
    plt.imshow(grid.numpy().transpose((1, 2, 0)), cmap='coolwarm')

# %%
plot_kernels(filters_loader[0], nrow=9)

# %%
plot_kernels(filters_loader[1], nrow=9)

# %%
plot_kernels(filters_loader[2], nrow=9)

# %% [markdown]
# # Prepare data

# %% [markdown]
# Now we load CIFAR10 and take a small subset of it. We restrict this subset to have equal number of images per class to make dataset balanced.

# %%
train_transform = transforms.Compose([transforms.ToTensor(),
                                      transforms.Normalize(0.5, 0.5)])
test_transform = transforms.Compose([transforms.ToTensor(),
                                     transforms.Normalize(0.5, 0.5)])

train_set = torchvision.datasets.CIFAR10('./cifar10', train=True, download=True,
                                         transform=train_transform)

test_set = torchvision.datasets.CIFAR10('./cifar10', train=False, download=True,
                                        transform=test_transform)

print('Train size', len(train_set))
print('Test size', len(test_set))
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar10/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./cifar10/cifar-10-python.tar.gz to ./cifar10
# Files already downloaded and verified
# Train size 50000
# Test size 10000

# %%
train_size = 100 / len(train_set)

# %%
train_idx, _ = train_test_split(np.arange(len(train_set)),
                                train_size=train_size,
                                shuffle=True,
                                random_state=42,
                                stratify=train_set.targets)

# %% [markdown]
# Let's make sure that the obtained indices are indeed stratified by classes.

# %%
pd.DataFrame(train_set.targets).rename(columns={0: 'class'}).iloc[train_idx].groupby('class').size()
# Out:
# class
# 0    10
# 1    10
# 2    10
# 3    10
# 4    10
# 5    10
# 6    10
# 7    10
# 8    10
# 9    10
# dtype: int64

# %%
train_set = Subset(train_set, train_idx)

# %%
img_bs = 16

train_loader = torch.utils.data.DataLoader(train_set, batch_size=img_bs, shuffle=True, num_workers=2)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=img_bs, shuffle=False, num_workers=2)

# %%
plot_random_images(train_loader)

# %%
plot_random_images(test_loader)

# %% [markdown]
# # Training on small dataset

# %%
class CNN(nn.Module):
    def __init__(self, num_classes=100):
        super(CNN, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(),

            nn.Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(),

            nn.Conv2d(128, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(),

            nn.Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False),
            nn.BatchNorm2d(256),
            nn.ReLU(),
        )
        self.classifier = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        batch_size = x.shape[0]
        x = self.features(x)
        x = self.classifier(x)
        return x

# %% [markdown]
# # Discriminators

# %%
RANDOM_SEED = 0

set_random_seeds(seed_value=RANDOM_SEED, device=device)

clf = CNN(num_classes=10).to(device)
print('Number of weights:', np.sum([np.prod(p.shape) for p in clf.parameters()]))
# Out:
# Number of weights: 922442

# %%
# Contain classifier's weights into dataset abstraction to yield stochastic mini-batches with gradients

diff_fake_filters = ParameterFilterDataset(clf.features[0])
diff_fake_loader = DataLoader(diff_fake_filters, batch_size=filter_bs, shuffle=True)

# %%
# custom weights initialization called on netD
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.main = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=(3, 3), padding=(1, 1), bias=False),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(64, 128, kernel_size=(3, 3), padding=(1, 1), bias=False),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),

            #nn.Conv2d(128, 1, kernel_size=(3, 3), padding=(1, 1), bias=False),
            #nn.Sigmoid()
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),
            nn.Linear(128, 1),
            nn.Sigmoid()
        )
    
    def forward(self, input):
        return self.main(input)

# %%
RANDOM_SEED = 0
set_random_seeds(seed_value=RANDOM_SEED, device=device)

netD = Discriminator().to(device)
netD.apply(weights_init)
print('Number of weights:', np.sum([np.prod(p.shape) for p in netD.parameters()]))
# Out:
# Number of weights: 74817

# %%
netD
# Out:
# Discriminator(
#   (main): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): LeakyReLU(negative_slope=0.2, inplace=True)
#     (6): AdaptiveAvgPool2d(output_size=1)
#     (7): Flatten(start_dim=1, end_dim=-1)
#     (8): Linear(in_features=128, out_features=1, bias=True)
#     (9): Sigmoid()
#   )
# )

# %%
# Initialize criterions for classifier and discriminator
criterion_clf = nn.CrossEntropyLoss()
criterion_D = nn.BCELoss()

# Establish convention for real and fake labels during training
real_label = 1.
fake_label = 0.

# Setup Adam optimizers for both classifier and discriminator
opt_clf = torch.optim.Adam(clf.parameters(), weight_decay=1e-4)
opt_D = torch.optim.Adam(netD.parameters(), lr=0.0002, betas=(0.5, 0.999))

# Set adversarial coefficient to scale generative and discriminative losses
adversarial_coef = 1.

# %%
def iter_discriminator(real_loader, fake_batch, netD, criterion_D, opt_D, adversarial_coef):
    netD.train()
    netD.zero_grad()
    #############################
    ## Train with all-real batch
    # Format batch
    real_batch = next(iter(real_loader)).to(device)
    b_size = real_batch.size(0)
    label = torch.full((b_size,), real_label, dtype=torch.float, device=device)
    # Forward pass real batch through D
    output = netD(real_batch).view(-1)
    # Calculate loss on all-real batch
    errD_real = adversarial_coef * criterion_D(output, label)
    # Calculate gradients for D in backward pass
    errD_real.backward()
    D_real = output.mean().item()

    #############################
    ## Train with all-fake batch
    # Format batch
    fake_batch = fake_batch.detach().to(device)
    b_size = fake_batch.size(0)
    label = torch.full((b_size,), fake_label, dtype=torch.float, device=device)
    # Classify all fake batch with D
    output = netD(fake_batch).view(-1)
    # Calculate D's loss on the all-fake batch
    errD_fake = adversarial_coef * criterion_D(output, label)
    # Calculate the gradients for this batch, accumulated with previous gradients
    errD_fake.backward()
    D_fake = output.mean().item()
    # Compute error of D as sum over the fake and real batches
    errD = errD_real + errD_fake
    # Update D
    opt_D.step()

    return errD.item(), D_real, D_fake

# %%
def epoch_train(img_loader, fake_loader, clf, netD, criterion_clf, criterion_G, opt_clf, adversarial_coef):
    G_losses = []
    D_losses = []
    prob_cond_real = []
    prob_cond_fake = []

    #############################
    ## Update classifier
    clf.train()
    for data, target in img_loader:
        data = data.to(device)
        #############################
        ## Classifier loss
        target = target.to(device)
        output_clf = clf(data)
        loss = criterion_clf(output_clf, target)

        #############################
        ## Generator loss
        # Format batch
        fake_batch = next(iter(fake_loader))
        b_size = fake_batch.size(0)
        # Fake labels are real for generator cost
        label = torch.full((b_size,), real_label, dtype=torch.float, device=device)
        # Forward pass fake batch through D
        output_D = netD(fake_batch).view(-1)
        # Calculate generative loss based on D's output
        errG = criterion_G(output_D, label)
        
        #############################
        # Accumulate losses
        loss += adversarial_coef * errG
        G_losses.append(errG.item())
        # Update gradients
        opt_clf.zero_grad()
        loss.backward()
        opt_clf.step()

        #############################
        ## Update discriminators
        errD, D_real, D_fake = iter_discriminator(real_loader, fake_batch, netD, criterion_D, opt_D, adversarial_coef)
        D_losses.append(errD)
        prob_cond_real.append(D_real)
        prob_cond_fake.append(D_fake)
    
    #############################
    ## Evaluation
    clf.eval()
    train_loss = 0
    with torch.no_grad():
        for data, target in img_loader:
            data = data.to(device)
            target = target.to(device)
            output = clf(data)
            train_loss += criterion_clf(output, target).item()
    train_acc = get_accuracy(clf, img_loader, device)
    train_loss /= len(img_loader)

    #############################
    ## Logging GAN statistics
    gan_stats = {}
    gan_stats['G_losses'] = G_losses
    gan_stats['D_losses'] = D_losses
    gan_stats['D_real'] = prob_cond_real
    gan_stats['D_fake'] = prob_cond_fake

    return train_loss, train_acc, gan_stats

# %%
def epoch_test(img_loader, clf, criterion_clf):
    clf.eval()
    test_loss = 0
    with torch.no_grad():
        for data, target in img_loader:
            data = data.to(device)
            target = target.to(device)
            output = clf(data)
            test_loss += criterion_clf(output, target).item()
    test_acc = get_accuracy(clf, img_loader, device)
    test_loss /= len(img_loader.dataset)
    return test_loss, test_acc

# %%
n_epochs = 1000

D_losses = []
G_losses = []
prob_cond_real = []
prob_cond_fake = []
test_scores = []

real_loader = filters_loader[0]

print("Starting Training Loop...")
for epoch in range(n_epochs):
    train_loss, train_acc, gan_stats = epoch_train(train_loader, diff_fake_loader, clf, netD, criterion_clf, criterion_D, opt_clf, adversarial_coef)

    errG = gan_stats['G_losses']
    errD = gan_stats['D_losses']
    D_real = gan_stats['D_real']
    D_fake = gan_stats['D_fake']

    if epoch % 10 == 9:
        test_loss, test_acc = epoch_test(test_loader, clf, criterion_clf)

        print(f'[Epoch {epoch + 1}] train loss: {train_loss:.3f}; train acc: {train_acc:.2f}; ' + 
              f'test loss: {test_loss:.3f}; test acc: {test_acc:.2f}')
        print(f'Discriminator loss: {np.mean(errD)}')
        print(f'Generator loss: {np.mean(errG)}')
        test_scores.append(test_acc)

    G_losses += errG
    D_losses += errD
    prob_cond_real += D_real
    prob_cond_fake += D_fake
# Out:
# Starting Training Loop...
# [Epoch 10] train loss: 0.055; train acc: 1.00; test loss: 0.140; test acc: 0.23
# Discriminator loss: 1.2628176382609777
# Generator loss: 0.7776392357689994
# [Epoch 20] train loss: 0.027; train acc: 1.00; test loss: 0.161; test acc: 0.21
# Discriminator loss: 1.1517167772565569
# Generator loss: 0.8337707264082772
# [Epoch 30] train loss: 0.029; train acc: 1.00; test loss: 0.177; test acc: 0.20
# Discriminator loss: 1.0556875807898385
# Generator loss: 0.9061910850661141
# [Epoch 40] train loss: 0.015; train acc: 1.00; test loss: 0.172; test acc: 0.18
# Discriminator loss: 0.9372392637389046
# Generator loss: 0.9826828241348267
# [Epoch 50] train loss: 0.003; train acc: 1.00; test loss: 0.175; test acc: 0.20
# Discriminator loss: 0.8442422321864537
# Generator loss: 1.057604125567845
# [Epoch 60] train loss: 0.008; train acc: 1.00; test loss: 0.194; test acc: 0.20
# Discriminator loss: 0.7680602158818927
# Generator loss: 1.1583971977233887
# [Epoch 70] train loss: 0.017; train acc: 1.00; test loss: 0.189; test acc: 0.19
# Discriminator loss: 0.7244342906134469
# Generator loss: 1.225299562726702
# [Epoch 80] train loss: 0.003; train acc: 1.00; test loss: 0.186; test acc: 0.21
# Discriminator loss: 0.8189306259155273
# Generator loss: 1.1586024505751473
# [Epoch 90] train loss: 0.002; train acc: 1.00; test loss: 0.196; test acc: 0.19
# Discriminator loss: 1.280449049813407
# Generator loss: 0.7710606626101902
# [Epoch 100] train loss: 0.003; train acc: 1.00; test loss: 0.199; test acc: 0.20
# Discriminator loss: 1.205567513193403
# Generator loss: 0.7865422197750637
# Discriminator loss: 1.3297077417373657
# Generator loss: 0.74230067219053
# [Epoch 860] train loss: 0.002; train acc: 1.00; test loss: 0.277; test acc: 0.18
# Discriminator loss: 1.3818339109420776
# Generator loss: 0.6975512760026115
# [Epoch 870] train loss: 0.003; train acc: 1.00; test loss: 0.281; test acc: 0.17
# Discriminator loss: 1.311337215559823
# Generator loss: 0.7504451019423348
# [Epoch 880] train loss: 0.012; train acc: 1.00; test loss: 0.343; test acc: 0.16
# Discriminator loss: 1.271859986441476
# Generator loss: 0.7718388182776315
# [Epoch 890] train loss: 0.000; train acc: 1.00; test loss: 0.278; test acc: 0.18
# Discriminator loss: 1.4333970035825456
# Generator loss: 0.685421313558306
# [Epoch 900] train loss: 0.014; train acc: 1.00; test loss: 0.301; test acc: 0.17
# Discriminator loss: 1.3932113817759924
# Generator loss: 0.6899291958127703
# [Epoch 910] train loss: 0.001; train acc: 1.00; test loss: 0.275; test acc: 0.16
# Discriminator loss: 1.2323599031993322
# Generator loss: 0.7771578090531486
# [Epoch 920] train loss: 0.000; train acc: 1.00; test loss: 0.279; test acc: 0.16
# Discriminator loss: 1.3659389870507377
# Generator loss: 0.7091322200638908
# [Epoch 930] train loss: 0.000; train acc: 1.00; test loss: 0.281; test acc: 0.17
# Discriminator loss: 1.4117245163236345
# Generator loss: 0.6567297407558986
# [Epoch 940] train loss: 0.000; train acc: 1.00; test loss: 0.282; test acc: 0.17
# Discriminator loss: 1.2618288823536463
# Generator loss: 0.756656961781638
# [Epoch 950] train loss: 0.000; train acc: 1.00; test loss: 0.281; test acc: 0.17
# Discriminator loss: 1.2610977377210344
# Generator loss: 0.7689057758876255
# [Epoch 960] train loss: 0.005; train acc: 1.00; test loss: 0.277; test acc: 0.18
# Discriminator loss: 1.360468898500715
# Generator loss: 0.7294909272875104
# [Epoch 970] train loss: 0.008; train acc: 1.00; test loss: 0.314; test acc: 0.16
# Discriminator loss: 1.3624907561710902
# Generator loss: 0.7121729339872088
# [Epoch 980] train loss: 0.000; train acc: 1.00; test loss: 0.271; test acc: 0.18
# Discriminator loss: 1.326744794845581
# Generator loss: 0.7539688093321664
# [Epoch 990] train loss: 0.000; train acc: 1.00; test loss: 0.273; test acc: 0.18
# Discriminator loss: 1.3296848705836706
# Generator loss: 0.7357154062816075
# [Epoch 1000] train loss: 0.001; train acc: 1.00; test loss: 0.276; test acc: 0.18
# Discriminator loss: 1.4180947712489538
# Generator loss: 0.6789143170629229

# %%
plt.figure(figsize=(12, 8))
plt.plot(D_losses, label='Discriminator loss')
plt.plot(G_losses, label='Regularization loss')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 8))
plt.plot(np.arange(1, 1001, 10), test_scores)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Test accuracy')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(prob_cond_real, label='P(real|real)')
plt.plot(prob_cond_fake, label='P(real|fake)')
plt.xlabel('Iteration')
plt.ylabel('Probability')
plt.legend()
plt.show()

# %%
filters_data = (FilterDataset([clf.to('cpu').features[0]]))

filters_loader = DataLoader(filters_data, batch_size=filter_bs, shuffle=False)

# %%
plot_kernels(filters_loader, nrow=9)
